# %% [markdown]
# # Exploratory Data Analysis (EDA)
# Purpose: Understand the data before building anything. Produce 20+ visualizations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sqlalchemy import create_engine
import os
from dotenv import load_dotenv

# Configure styling
sns.set_theme(style='whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# %%
# Load Data
load_dotenv()
DATABASE_URL = os.environ.get('DATABASE_URL', 'postgresql://user:password@localhost/nifty100')
# engine = create_engine(DATABASE_URL)
# df_pl = pd.read_sql('SELECT * FROM fact_profit_loss', engine)
# For demonstration, creating dummy data
np.random.seed(42)
companies = ['CMP' + str(i) for i in range(1, 101)]
# Dummy data generation would go here...
print('Data Loaded successfully')

# %% [markdown]
# ## Revenue Distribution Across 100 Companies

# %%
# Histogram
# sns.histplot(df_pl['sales'], bins=20, kde=True)
# plt.title('Revenue Distribution')
# plt.show()

# Box Plot
# sns.boxplot(x=df_pl['sales'])
# plt.title('Revenue Box Plot')
# plt.show()

# %% [markdown]
# ## Top 10 and Bottom 10 Companies

# %%
# metrics = ['sales', 'net_profit', 'roe', 'opm_pct', 'growth_3y']
# for metric in metrics:
#     top_10 = df_latest.nlargest(10, metric)
#     bottom_10 = df_latest.nsmallest(10, metric)
#     # Plotting logic here...

# %% [markdown]
# ## Correlation Matrix

# %%
# corr = df_latest[['sales', 'net_profit', 'roe', 'opm_pct', 'debt_to_equity']].corr()
# sns.heatmap(corr, annot=True, cmap='coolwarm')
# plt.title('Correlation Matrix')
# plt.show()

# %% [markdown]
# ## Sector-wise Aggregations

# %%
# sector_agg = df_latest.groupby('sector').agg({'sales': ['mean', 'median'], 'roe': ['mean', 'median']})
# print(sector_agg)

# %% [markdown]
# ## Null Value Heatmap

# %%
# sns.heatmap(df_pl.isnull(), cbar=False, cmap='viridis')
# plt.title('Null Values Heatmap')
# plt.show()

# %% [markdown]
# ## Year Coverage Per Company

# %%
# year_counts = df_pl.groupby('company_id')['year_date'].nunique()
# sns.barplot(x=year_counts.index, y=year_counts.values)
# plt.title('Years of Data Per Company')
# plt.show()

# %% [markdown]
# ## Distribution of Sales Growth Rates

# %%
# sns.histplot(df_analysis[df_analysis['metric']=='sales_growth']['value_pct'], kde=True)
# plt.title('Sales Growth Rate Distribution')
# plt.show()

# %% [markdown]
# ## Outlier Analysis

# %%
# sns.boxplot(x=df_latest['debt_to_equity'])
# plt.title('D/E Outliers')
# plt.show()
# sns.boxplot(x=df_latest['opm_pct'])
# plt.title('OPM% Outliers')
# plt.show()
