# %% [markdown]
# # Sector Clustering
# Purpose: Unsupervised ML to find clusters of similar companies.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA

# %% [markdown]
# ## Feature Engineering & Normalization

# %%
# features = ['avg_opm', 'avg_roe', 'avg_growth_3y', 'avg_debt_to_equity', 'avg_cash_conversion', 'avg_dividend']
# X = df_features[features].fillna(0)
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## K-Means & Elbow Method

# %%
# inertias = []
# for k in range(2, 10):
#     kmeans = KMeans(n_clusters=k, random_state=42).fit(X_scaled)
#     inertias.append(kmeans.inertia_)
# plt.plot(range(2, 10), inertias, marker='o')
# plt.title('Elbow Method')
# plt.show()

# kmeans = KMeans(n_clusters=5, random_state=42).fit(X_scaled)
# df_features['cluster_kmeans'] = kmeans.labels_

# %% [markdown]
# ## DBSCAN

# %%
# dbscan = DBSCAN(eps=1.5, min_samples=3)
# df_features['cluster_dbscan'] = dbscan.fit_predict(X_scaled)

# %% [markdown]
# ## PCA Visualization

# %%
# pca = PCA(n_components=2)
# X_pca = pca.fit_transform(X_scaled)
# sns.scatterplot(x=X_pca[:,0], y=X_pca[:,1], hue=df_features['cluster_kmeans'], palette='viridis')
# plt.title('Clusters visualized with PCA')
# plt.show()

# %% [markdown]
# ## Cluster Labelling & Sector Comparison

# %%
# pd.crosstab(df_features['cluster_kmeans'], df_features['sector'])
