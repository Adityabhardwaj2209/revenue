# %% [markdown]
# # Anomaly Detection
# Purpose: Find unusual financial patterns using statistical and ML techniques.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.ensemble import IsolationForest

# %% [markdown]
# ## Z-Score Anomaly Detection

# %%
# Calculate Z-scores for sales, net_profit, borrowings, operating_profit across years per company
# df_pl['z_sales'] = df_pl.groupby('company_id')['sales'].transform(lambda x: stats.zscore(x, ddof=1))
# anomalies_z = df_pl[df_pl['z_sales'].abs() > 3]

# %% [markdown]
# ## Isolation Forest

# %%
# features = ['sales', 'net_profit', 'borrowings', 'operating_profit']
# iso = IsolationForest(contamination=0.05, random_state=42)
# df_pl['anomaly_iso'] = iso.fit_predict(df_pl[features].fillna(0))
# anomalies_iso = df_pl[df_pl['anomaly_iso'] == -1]

# %% [markdown]
# ## Visualizing Anomalies on Timeline

# %%
# sns.scatterplot(x='year_date', y='sales', hue='anomaly_iso', data=df_pl[df_pl['company_name']=='ADANIPOWER'])
# plt.title('Anomalies for Adani Power')
# plt.show()

# %% [markdown]
# ## Export Anomaly Flags

# %%
# anomaly_flags = df_pl[['company_id', 'year_date', 'anomaly_iso']]
# anomaly_flags.to_csv('../data/fact_anomaly_flags.csv', index=False)
